# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshCS23034/machine-learning-practicals/blob/main/ML_Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Harsh Dhawale
# **CS23034**

# %%
# Aim: to apply principle component analysis for dimensionality reduction and visualize the transformed feature space.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Variance Ratio :", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio : [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:,1],c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization")
plt.colorbar()
plt.show()

# %%
pca = PCA()
pca.fit(X_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Explained Variance by Components")
plt.show()
